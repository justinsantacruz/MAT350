# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2*np.pi, 60)
y = np.sin(x)
plt.plot(x,y,'g')
plt.plot(x,y,marker='^', label='sin', linestyle='-.')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title("generic sinusoidal function")
# Out:
# Text(0.5, 1.0, 'generic sinusoidal function')
